# %% [markdown]
# We use Distribution plot to visualise the distribution of quantitative data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Now, Seaborn has a lot of amount of dataset on their GituHub: https://github.com/mwaskom/seaborn-data
# <br>
# one of the dataset name is: tips.csv

# %%
df=sns.load_dataset("tips") #make sure your internet is on while loading a dataset from seaborn
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['size'].unique()#gives only the unique values of the size column
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
sns.displot(df["total_bill"])

# %%
sns.displot(df["total_bill"],bins=25)

# %% [markdown]
# Let's draw a kernal distributing estimator

# %%
sns.histplot(df["total_bill"],bins=20 ,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
plt.subplot(1,2,1)
sns.histplot(df["total_bill"],kde=True)
plt.subplot(1,2,2)
sns.histplot(df["tip"],kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# If I want to compare to plots...

# %%
sns.jointplot(x='total_bill',y='tip',data=df)#by default it will give a scatter plot

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='kde')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='tip',palette='rainbow')
