# %%
import numpy as np
import pandas as pd

# %%
#series = 1D list which can store multiple data type
#labels are used for indexes
labels=['a','b','c']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={"one":10,"two":20,"three":30}

# %%
pd.Series(my_list)#will print all the values of list 'my_list' alongside indexes
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
#will print all the values of list 'my_list' with indexes being a,b and c
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# one      10
# two      20
# three    30
# dtype: int64

# %%
k=np.array([[1,2,3],[4,5,6]])
#pd.Series(k)will throw an error
k
