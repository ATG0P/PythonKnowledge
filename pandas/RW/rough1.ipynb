# %%
import numpy as np
import pandas as pd

# %%
a = [2,3,4]
b=['a','b','c']
pd.Series(a,index=b)
# Out:
# a    2
# b    3
# c    4
# dtype: int64

# %%
arr = {
    "one": [1,2,3],
    "two": [4,5,6],
    "three": [7,8,9]
}

# %%
pd.DataFrame(arr)
# Out:
#    one  two  three
# 0    1    4      7
# 1    2    5      8
# 2    3    6      9

# %%
arr2=[["Aryan","Sunil","Dahiya"],["Shlok","Navin","Shtty"]]
pd.DataFrame(arr2)
# Out:
#        0      1       2
# 0  Aryan  Sunil  Dahiya
# 1  Shlok  Navin   Shtty

# %%
NameFormat=["Name","Middle Name","Surnname"]
arr2=pd.DataFrame(arr2,columns=NameFormat)
arr2
# Out:
#     Name Middle Name Surnname
# 0  Aryan       Sunil   Dahiya
# 1  Shlok       Navin    Shtty

# %%
arr2.index=["a","b"]
arr2
# Out:
#     Name Middle Name Surnname
# a  Aryan       Sunil   Dahiya
# b  Shlok       Navin    Shtty

# %%
arr2["Name"]
# Out:
# a    Aryan
# b    Shlok
# Name: Name, dtype: object

# %%
arr2["J*B"]=["AIML Engineer","J*bless"]
arr2
# Out:
#     Name Middle Name Surnname            J*B
# a  Aryan       Sunil   Dahiya  AIML Engineer
# b  Shlok       Navin    Shtty        J*bless

# %%
arr2.drop("J*B",axis=1)
# Out:
#     Name Middle Name Surnname
# a  Aryan       Sunil   Dahiya
# b  Shlok       Navin    Shtty

# %%
arr2
# Out:
#     Name Middle Name Surnname            J*B
# a  Aryan       Sunil   Dahiya  AIML Engineer
# b  Shlok       Navin    Shtty        J*bless

# %%
arr2.drop("J*B",axis=1,inplace=True)
arr2
# Out:
#     Name Middle Name Surnname
# a  Aryan       Sunil   Dahiya
# b  Shlok       Navin    Shtty

# %%
arr2
# Out:
#     Name Middle Name Surnname
# a  Aryan       Sunil   Dahiya
# b  Shlok       Navin    Shtty

# %%
arr2.drop("b",axis=0)
# Out:
#     Name Middle Name Surnname
# a  Aryan       Sunil   Dahiya

# %%
arr2
# Out:
#     Name Middle Name Surnname
# a  Aryan       Sunil   Dahiya
# b  Shlok       Navin    Shtty

# %%
arr2.loc["a"]
# Out:
# Name            Aryan
# Middle Name     Sunil
# Surnname       Dahiya
# Name: a, dtype: object

# %%
arr2.loc[["a","b"]]
# Out:
#     Name Middle Name Surnname
# a  Aryan       Sunil   Dahiya
# b  Shlok       Navin    Shtty
