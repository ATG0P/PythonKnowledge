# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    445     28   John  January      Q1
# 1  2023-01-02       B   West    156     82   Mary  January      Q1
# 2  2023-01-03       C  North    707     80    Bob  January      Q1
# 3  2023-01-04       D  South    626     48  Alice  January      Q1
# 4  2023-01-05       A   East    377     65   John  January      Q1
# 5  2023-01-06       B   West    470     19   Mary  January      Q1
# 6  2023-01-07       C  North    148     52    Bob  January      Q1
# 7  2023-01-08       D  South    529     56  Alice  January      Q1
# 8  2023-01-09       A   East    693     79   John  January      Q1
# 9  2023-01-10       B   West    947     29   Mary  January      Q1
# 10 2023-01-11       C  North    129     50    Bob  January      Q1
# 11 2023-01-12       D  South    844     74  Alice  January      Q1
# 12 2023-01-13       A   East    836     42   John  January      Q1
# 13 2023-01-14       B   West    743     52   Mary  January      Q1
# 14 2023-01-15       C  North    900     87    Bob  January      Q1
# 15 2023-01-16       D  South    106     22  Alice  January      Q1
# 16 2023-01-17       A   East    820     63   John  January      Q1
# 17 2023-01-18       B   West    665     51   Mary  January      Q1
# 18 2023-01-19       C  North    331     30    Bob  January      Q1
# 19 2023-01-20       D  South    435     91  Alice  January      Q1

# %%
pd.pivot_table(df,values="Sales",index="Region",columns="Product",aggfunc="median")
# Out:
# Product      A      B      C      D
# Region
# East     693.0    NaN    NaN    NaN
# North      NaN    NaN  331.0    NaN
# South      NaN    NaN    NaN  529.0
# West       NaN  665.0    NaN    NaN

# %%
pivot1=pd.pivot_table(df,values=["Sales","Units"],index="Region",columns="Product")
pivot1
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     634.2    NaN    NaN    NaN  55.4   NaN   NaN   NaN
# North      NaN    NaN  443.0    NaN   NaN   NaN  59.8   NaN
# South      NaN    NaN    NaN  508.0   NaN   NaN   NaN  58.2
# West       NaN  596.2    NaN    NaN   NaN  46.6   NaN   NaN

# %%
pd.crosstab(df["Region"],df["Product"])#it uses count function
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %%
df.groupby(["Region","Product"])["Sales"].sum()
# Out:
# Region  Product
# East    A          3171
# North   C          2215
# South   D          2540
# West    B          2981
# Name: Sales, dtype: int64
