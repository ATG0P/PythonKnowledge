# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
sample = [172, 174, 168, 169, 171, 173, 175, 170, 169, 172]
sample_mean = np.mean(sample)
sample_mean 
pop_mean = 170
pop_std = 3
n = len(sample)

# %%
z_score = (sample_mean-pop_mean)/(pop_std/np.sqrt(n))
z_score
# Out:
# np.float64(1.3703203194063098)

# %%
p_value = 2*(1-norm.cdf(z_score))
p_value
# Out:
# np.float64(0.17058693287143756)

# %%
alpha = 0.05
if p_value<=alpha and p_value>=(1-alpha):
    print("null hyposthesis rejected")
else:
    print("null hypothesis accepted")
# Out:
# null hypothesis accepted

# %% [markdown]
# QUESTION
# <P>A company claims that it's new software bug fix takes more than 30 mins on avg
# <p>A sample of 36 fixes shows an average time of 32 mins
# <p>Population standard deviation is known to be 6 minutes
# <p>Test the company's claim at the 0.01 significance level

# %%
pop_mean = 30
sample_mean=32
pop_std = 6
alpha = 0.01

# %%
z_score = (sample_mean-pop_mean)/(pop_std/np.sqrt(36))
z_score
# Out:
# np.float64(2.0)

# %%
p_value = 1-(norm.cdf(z_score))
p_value
# Out:
# np.float64(0.02275013194817921)

# %%
# Out:
# Null Hypothesis accepted
